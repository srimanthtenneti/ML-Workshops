# %% [markdown]
# <a href="https://colab.research.google.com/github/srimanthtenneti/ML-Workshops/blob/main/ML101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Machine Learning
#
# Hello Everyone I am Srimanth Tenneti the Machine Learning Lead at DSC CVR and I would be your instructor for today. This notebook is your entry to the beautiful work of machine learning and I hope you enjoy it. We are going to use Sklearn , numpy and matplotlib to build our Machine Learning models.
#
# ![yodaml.jpg](data:image/jpeg;base64,...)
#
# ##What are we going to learn ? : Time : 2hrs
#
# ###Introduction :  - Duration 30 mins
#
# 1. What is ML , Deep Learning and AI ?
#
# 2. Basic ML pre-requsites
#
#     2.1 Introduction to numpy
#
#     2.2 Introduction to pandas
#
#     2.3 Introduction to matplotlib
#
# 3. Introduction to sklearn
#
#
# ###Core topics: Duration 1 hour
#
# 1. What is regression ?
# 2. Linear regression theory
# 3. Implementing linear regresion
# 4. Polynomial regression theory
# 5. Implementing polynomial regression
# 6. Introduction to classification
# 7. Difference between regression and classification ?
# 8. K-Means theory
# 9. Implementing K-Means
#
# ###QnA: Duration 30 mins

# %% [markdown]
# ## Introduction to numpy
#
# ###Tasks
#
#
# 1. Converting a list into a numpy array
# 2. Reshaping numpy arrays
# 3. Matrix multiplications
# 4. Log , exp and root functions
# 5. Numpy Random

# %%
import numpy as np

# %% [markdown]
# ## Introduction to pandas
#
# ### Tasks
#
# 1. Creating a dataframe
# 2. Looking at the data
# 3. Looking at the brief description of data
# 4. Looking at the statistical parameters of the data
# 5. Indexing and slicing
# 6. Finding elements using specific keys
# 7. Reading a CSV file
# 8. Creating pandas series

# %%
import pandas as pd

# %% [markdown]
# ##Introduction to Matplotlib
# ### Tasks
#
# 1. Using the plot function
# 2. Using the hist function
# 3. Using the scatter function
# 4. Creating subplots
# 5. Using Tight Layout

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## SKlearn
#
# A typical data scientist's life.
#
# ![download.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Regression

# %% [markdown]
# #### Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# For complex datasets
#
# ![ResizerImage155X204.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ### Classification
# ![km2.jpg](data:image/jpeg;base64,...)

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# In simple
#
# ![kmemes.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Conclusion
# Cheers guys you have completed the workshop and now are ready to dive deep into the work of machine learning.
#
# ![images.jpg](data:image/jpeg;base64,...)
